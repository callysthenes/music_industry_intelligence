# %%
#################https://blog.devgenius.io/spotify-data-analysis-with-python-a727542beaa7
# !pip install spotipy
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Collecting spotipy
#   Downloading spotipy-2.20.0-py3-none-any.whl (27 kB)
# Collecting requests>=2.25.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 357.5 kB/s eta 0:00:000:00:010:00:01
# Collecting redis>=3.5.3
#   Downloading redis-4.3.4-py3-none-any.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.2/246.2 kB 481.1 kB/s eta 0:00:001m482.3 kB/s eta 0:00:01
# Collecting six>=1.15.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /home/callysthenes/snap/jupyter/common/lib/python3.7/site-packages (from spotipy) (1.26.12)
# Collecting async-timeout>=4.0.2
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: packaging>=20.4 in /home/callysthenes/snap/jupyter/common/lib/python3.7/site-packages (from redis>=3.5.3->spotipy) (21.3)
# Requirement already satisfied: typing-extensions in /home/callysthenes/snap/jupyter/common/lib/python3.7/site-packages (from redis>=3.5.3->spotipy) (4.4.0)
# Collecting importlib-metadata>=1.0
#   Downloading importlib_metadata-5.0.0-py3-none-any.whl (21 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 538.4 kB/s eta 0:00:00m eta 0:00:010:01
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /snap/jupyter/6/lib/python3.7/site-packages (from requests>=2.25.0->spotipy) (2019.3.9)
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.14.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.2/75.2 kB 483.1 kB/s eta 0:00:001m500.8 kB/s eta 0:00:01
# Collecting zipp>=0.5
#   Downloading zipp-3.9.0-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/callysthenes/snap/jupyter/common/lib/python3.7/site-packages (from packaging>=20.4->redis>=3.5.3->spotipy) (3.0.9)
# Installing collected packages: zipp, wrapt, six, idna, charset-normalizer, async-timeout, requests, importlib-metadata, deprecated, redis, spotipy
# Successfully installed async-timeout-4.0.2 charset-normalizer-2.1.1 deprecated-1.2.13 idna-3.4 importlib-metadata-5.0.0 redis-4.3.4 requests-2.28.1 six-1.16.0 spotipy-2.20.0 wrapt-1.14.1 zipp-3.9.0
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: pip install --upgrade pip

# %%
import configparser
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#read config file with configparser
config = configparser.ConfigParser()
config.read('config.ini')
# Out:
# ['config.ini']

# %%
#store credentials in variables
CLIENT_ID=config['spotify']['client_id']
CLIENT_SECRET=config['spotify']['client_secret']

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
print(sp)
# Out:
# <spotipy.client.Spotify object at 0x7fae2fc76e10>

# %%
artist_name = []
track_name = []
track_popularity = []
artist_id = []
track_id = []
for i in range(0,1000,50):
    track_results = sp.search(q='year:2021', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        track_popularity.append(t['popularity'])

# %%
import pandas as pd
track_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'track_popularity' : track_popularity, 'artist_id' : artist_id})
print(track_df.shape)
track_df.head()
# Out:
# (1000, 5)
#        artist_name                                   track_name  \
# 0      Nicky Youre                                      Sunroof
# 1    Morgan Wallen                                Wasted On You
# 2            Drake  Knife Talk (with 21 Savage ft. Project Pat)
# 3  Stephen Sanchez                            Until I Found You
# 4            Drake             Wants and Needs (feat. Lil Baby)
#
#                  track_id  track_popularity               artist_id
# 0  4h4QlmocP3IuwYEj2j14p8                92  7qmpXeNz2ojlMl2EEfkeLs
# 1  3cBsEDNhFI9E82vPj3kvi3                83  4oUHIQIBe0LHzYfvXNW4QM
# 2  2BcMwX1MPV6ZHP4tUT9uq6                85  3TVXtAsR1Inumwj472S9r4
# 3  0T5iIrXA4p5GsubkhuBIKV                90  5XKFrudbV4IiuE5WuTPRmT
# 4  65OVbaJR5O1RmwOQx0875b                84  3TVXtAsR1Inumwj472S9r4

# %%
artist_popularity = []
artist_genres = []
artist_followers = []
for a_id in track_df.artist_id:
  artist = sp.artist(a_id)
  artist_popularity.append(artist['popularity'])
  artist_genres.append(artist['genres'])
  artist_followers.append(artist['followers']['total'])

# %%
track_df = track_df.assign(artist_popularity=artist_popularity, artist_genres=artist_genres, artist_followers=artist_followers)
track_df.head()
# Out:
#        artist_name                                   track_name  \
# 0      Nicky Youre                                      Sunroof
# 1    Morgan Wallen                                Wasted On You
# 2            Drake  Knife Talk (with 21 Savage ft. Project Pat)
# 3  Stephen Sanchez                            Until I Found You
# 4            Drake             Wants and Needs (feat. Lil Baby)
#
#                  track_id  track_popularity               artist_id  \
# 0  4h4QlmocP3IuwYEj2j14p8                92  7qmpXeNz2ojlMl2EEfkeLs
# 1  3cBsEDNhFI9E82vPj3kvi3                83  4oUHIQIBe0LHzYfvXNW4QM
# 2  2BcMwX1MPV6ZHP4tUT9uq6                85  3TVXtAsR1Inumwj472S9r4
# 3  0T5iIrXA4p5GsubkhuBIKV                90  5XKFrudbV4IiuE5WuTPRmT
# 4  65OVbaJR5O1RmwOQx0875b                84  3TVXtAsR1Inumwj472S9r4
#
#    artist_popularity                                      artist_genres  \
# 0                 75                                                 []
# 1                 84                    [contemporary country, country]
# 2                 95  [canadian hip hop, canadian pop, hip hop, rap,...
# 3                 76                     [gen z singer-songwriter, pop]
# 4                 95  [canadian hip hop, canadian pop, hip hop, rap,...
#
#    artist_followers
# 0             69944
# 1           4127356
# 2          67730642
# 3            251251
# 4          67730642

# %%
print(track_results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=year%3A2021&type=track&offset=950&limit=50', 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'}, 'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02', 'id': '06HL4z0CvFAxyc27GXpf02', 'name': 'Taylor Swift', 'type': 'artist', 'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/6AORtDjduMM3bupSWzbTSG'}, 'href': 'https://api.spotify.com/v1/albums/6AORtDjduMM3bupSWzbTSG', 'id': '6AORtDjduMM3bupSWzbTSG', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27390fd9741e1838115cd90b3b6', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0290fd9741e1838115cd90b3b6', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485190fd9741e1838115cd90b3b6', 'width': 64}], 'name': 'evermore (deluxe version)', 'release_date': '2021-01-07', 'release_date_precision': 'day', 'total_tracks': 17, 'type': 'album', 'uri': 'spotify:album:6AORtDjduMM3bupSWzbTSG'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'}, 'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02', 'id': '06HL4z0CvFAxyc27GXpf02', 'name': 'Taylor Swift', 'type': 'artist', 'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'disc_number': 1, 'duration_ms': 245440, 'explicit': True, 'external_ids': {'isrc': 'USUG12004705'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/6lCvK2AR2uOKkVFCVlAzzm'}, 'href': 'https://api.spotify.com/v1/tracks/6lCvK2AR2uOKkVFCVlAzzm', 'id': '6lCvK2AR2uOKkVFCVlAzzm', 'is_local': False, 'name': 'tole ...
